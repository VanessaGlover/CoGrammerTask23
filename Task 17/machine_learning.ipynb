# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)    | Output     |
# | ---- | ----------- | ---------  |
# | 1.1  | Autonomous Car            | Sensors                   |The input data provides the necessary information for the self-driving car to perceive its environment and make driving decisions. The output is based on the input data and the car's internal algorithms, enabling it to navigate safely and efficiently.
#
# | 1.2  | User data                 | Viewing history           |The input data provides insights into user preferences, which the recommendation system uses to generate personalised recommendations. The output recommendations aim to enhance user satisfaction and engagement with the Netflix platform.
#
# | 1.3  | Pattern                   | Pattern reference         |The input data provides information about the signature's visual characteristics, which the recognition system analyses to determine the signer's identity or authenticity. The output aims to authenticate signatures and prevent fraudulent activities.
#
# | 1.4  | Treatment                 | Diagnosis                 |The input data provides comprehensive information about the patient's health status, which the diagnostic system analyses to identify potential diseases or health conditions. The output aims to guide healthcare providers in making informed decisions about patient care and management.

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1 Classification because it can learn to make the difference between different classes by training on labeled data. Then it can use the patterns and relationships in the features to predicit the class labels of unseen data points.
# * 2.2 Regression because it is used to analyse historical data and identify patterns and relationships, in this case it will make predictions about the future stock prices based on those patterns.
# * 2.3 Classification because it can be used to analyse visual features of the images and learn patterns and relationships that differentiate between different animal species. It will then make predictions about the species label of unseen images based on the learned patterns.
# * 2.4 Classification because can be used to analyse the patient data and learn patterns and relationships that separates patients with and without disease. Then predictions can be made about the likelihood of the disease based on the learned patterns.

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1 Unsupervised learning- because there is no prior knowledge of specific anomanly patterns, and the goal is to detect anomalies in the manfacturing process using sensor data.
# * 3.2 Supervised learning- becuase the customer lifetime value is known and historical data is available.
# * 3.3 Unsupervised learning- because there are no predefined labels or target variables and the goal is find hidden patterns and structures in data.
# * 3.4 Unsupervised learning- because catergorising social media posts into different themes can be approached using this type of learning.

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# *4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1 Appropriate- because semi-supervised learning can be used to utilise both labeled and unlabeled data to refine the decision boundary between fraudulent and legitimate transactions.
# * 4.2 Appropriate- because the labeled data here can be used to train a model, then the unlabeled data can be used to extract additional information and patters.
# * 4.3 Inappropriate- because semi-supervised learning typically works best when there is a lrage amount of unlabeled data available.
# * 4.4 Inappropriate- because there is enough labeled daya available for supervised learning to bee used.
